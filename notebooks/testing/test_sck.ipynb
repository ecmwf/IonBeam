# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install wurlitzer

# %%
# %load_ext wurlitzer

# %%
import pandas as pd
import numpy as np
import logging
logging.basicConfig(level = logging.INFO)

# %%
import pyfdb
import findlibs
import yaml
from pathlib import Path
import os
import pandas as pd
import pyodc
import shutil

fdb5_path = Path(findlibs.find("fdb5"))
metkit_path = Path(findlibs.find("metkit"))
print(f"Using fdb5 shared library from {fdb5_path}")
print(f"Using metkit shared library from {metkit_path}")

marsrequest = (metkit_path.parents[1] / "share/metkit/odb/marsrequest.yaml").resolve()
languages = (metkit_path.parents[1] / "share/metkit/language.yaml").resolve() 

print(f"\nContents of {marsrequest}:\n", marsrequest.open().read())

fields = " ".join(yaml.safe_load(languages.open().read())["_field"].keys())
print(f"Fields defined in {languages}:\n {fields}")
# Out:
# Using fdb5 shared library from /Users/math/micromamba/envs/ionbeam/lib/libfdb5.dylib
# Using metkit shared library from /Users/math/micromamba/envs/ionbeam/lib/libmetkit.dylib
#
# Contents of /Users/math/micromamba/envs/ionbeam/share/metkit/odb/marsrequest.yaml:
#  ---
# PLATFORM: platform
# OBSERVATION_VARIABLE: observation_variable
# Fields defined in /Users/math/micromamba/envs/ionbeam/share/metkit/language.yaml:
#  observation_variable platform class type stream expver dataset model repres obsgroup reportype levtype levelist param date hdate offsetdate fcmonth fcperiod time offsettime step anoffset reference number quantile domain frequency direction diagnostic iteration channel ident instrument method origin system

# %%
from pathlib import Path
from ionbeam.core.config_parser import parse_config
from ionbeam.core.bases import *
from IPython.display import display

config_file = Path("~/git/IonBeam-Deployment/config/ionbeam").expanduser()
config, actions = parse_config(config_file,
                    config_path = "./",
                    data_path = "../data/",
                    offline = True,
                    environment  = "local",
                    sources = ["smart_citizen_kit"]
                    )
# Out:
# WARNING:ionbeam.core.config_parser.config_parser:Configuration Directory: /Users/math/git/IonBeam-Deployment/config/ionbeam
# WARNING:ionbeam.core.config_parser.config_parser:Global config file: /Users/math/git/IonBeam-Deployment/config/ionbeam/config.yaml

# %%
from uuid import UUID

id2action = {a.id : a for a in actions}
sources = [a for a in actions if isinstance(a, Source)]
processors = [a for a in actions if not isinstance(a, Source)]

chains = [[s,] for s in sources]
for a in processors:
    if not isinstance(a.match, UUID): 
        chains.append([str(a.match), a,])
        continue
    for c in chains:
        matches = a.match.int == c[-1].id.int
        if matches: c.append(a)
            

for c in chains:
    print(" --> ".join(str(a) for a in c))
# Out:
# SmartCitizenKitSource --> CSVParser --> GenerateMetaData --> TimeAggregator --> ODCEncoder
# [Match(state = 'odc_encoded')] --> RESTWriter()

# %%
sources, stateless_actions, aggregators = [], [], []
for action in actions:
    if isinstance(action, Source):
        sources.append(action)
    elif isinstance(action, Aggregator):
        aggregators.append(action)
    else:
        stateless_actions.append(action)

print("Sources")
for i, a in enumerate(sources):
    display(a)

print("Aggregators")
for i, a in enumerate(aggregators):
    display(a)

print("Actions")
for i, a in enumerate(stateless_actions):
    display(a)
# Out:
# Sources
# SmartCitizenKitSource(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), globals=Globals(canonical_variables=[CanonicalVariable(name='time', unit=None, desc='The time that the observation was made.'), CanonicalVariable(name='offset_tz', unit=None, desc='Uncertain what this means in the Meteotracker data.'), CanonicalVariable(name='lat', unit='°', desc='The lattitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='lon', unit='°', desc='The longitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='altitude', unit='m', desc='The altitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='author', unit=None, desc='The author field from the Meteotracker data'), CanonicalVariable(name='track_id', unit=None, desc='A unique identifer for a single recorded track from a mobile sensor.'), CanonicalVariable(name='station_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='created_at', unit=None, desc=None), CanonicalVariable(name='city', unit=None, desc=None), CanonicalVariable(name='country', unit=None, desc=None), CanonicalVariable(name='sensor_type', unit=None, desc=None), CanonicalVariable(name='location', unit=None, desc=None), CanonicalVariable(name='observation_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='air_temperature_near_surface', unit='K', desc=None), CanonicalVariable(name='relative_humidity_near_surface', unit='%', desc=None), CanonicalVariable(name='humidity_index', unit='K', desc=None), CanonicalVariable(name='internal_temperature', unit='K', desc='The internal temperature of the sensor.'), CanonicalVariable(name='vertical_temperature_gradient', unit='°C/100m', desc=None), CanonicalVariable(name='air_pressure_near_surface', unit='Pa', desc=None), CanonicalVariable(name='pressure_sealevel', unit='Pa', desc=None), CanonicalVariable(name='co2', unit='ppm', desc=None), CanonicalVariable(name='wind_gust', unit='m.s-1\xa0', desc=None), CanonicalVariable(name='wind_gust_direction', unit='°', desc=None), CanonicalVariable(name='dew_point_temperature', unit='K', desc=None), CanonicalVariable(name='wind_direction_near_surface', unit='°', desc=None), CanonicalVariable(name='wind_speed_near_surface', unit='m/s', desc=None), CanonicalVariable(name='rain', unit='mm', desc=None), CanonicalVariable(name='wind_direction', unit='Degrees', desc=None), CanonicalVariable(name='anemometer', unit='m/s', desc=None), CanonicalVariable(name='radiometer', unit='W/m^2', desc=None), CanonicalVariable(name='battery_level', unit='V', desc=None), CanonicalVariable(name='thermometer_min', unit='K', desc=None), CanonicalVariable(name='thermometer_max', unit='K', desc=None), CanonicalVariable(name='signal_strength', unit='CSQ', desc=None), CanonicalVariable(name='altitude', unit='m', desc=None), CanonicalVariable(name='solar_radiation_index', unit='1', desc=None), CanonicalVariable(name='bluetooth_RSSI', unit='dBm', desc=None), CanonicalVariable(name='carbon_dioxide', unit='ppm', desc=None), CanonicalVariable(name='carbon_monoxide', unit='ppm', desc=None), CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_4', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_3', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_5', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_1', unit='#/cm3', desc=None), CanonicalVariable(name='particulate ...
#     "schemas": [
#         [
#             "class",
#             "expver",
#             "stream",
#             "date",
#             "time",
#             [
#                 "platform",
#                 [
#                     "observation_variable"
#                 ]
#             ]
#         ]
#     ],
#     "defaults": {}
# }, secrets={'headers': {'User-Agent': 'ECMWF IOT Scraper', 'From': 'thomas.hodson@ecmwf.int'}, 'ACRONET': {'client_id': 'webdrops', 'client_secret': '099803eb-08e5-4e4b-a3ca-70f13cfe1147', 'username': 'ichange.downloader', 'password': 'uD/lIhNLT7weDV98'}, 'MeteoTracker_API': {'email': 'thomas.hodson@ecmwf.int', 'password': 'Iiv3SY7vP8jLMaLY'}, 'polytope': {'user_email': 'thomas.hodson@ecmwf.int', 'user_key': '45fc8b2b2a894448d905420a151dccd6'}, 'breathe_london': {'api_key': 'a6f13cb4-b753-11ec-b909-0242ac120002'}, 'postgres_database': {'username': 'postgres', 'password': 'g7HEuiMHJTKczM4k'}}, api_hostname='http://localhost:5002/api/v1/', postgres_database={'host': 'localhost', 'port': 5432}, namespace='local_schema', actions={UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'): ..., UUID('98cef1b2-a331-42b3-9f31-dcfdc2acf4e2'): CSVParser(metadata=MetaData(source_action_id=UUID('98cef1b2-a331-42b3-9f31-dcfdc2acf4e2'), state='parsed', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('98cef1b2-a331-42b3-9f31-dcfdc2acf4e2'), globals=..., match=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), identifying_columns=[InputColumn(name='time', key='time', type='datetime', unit=None, discard=False, canonical_variable=CanonicalVariable(name='time', unit=None, desc='The time that the observation was made.'))], value_columns=[InputColumn(name='total_volatile_organic_compounds', key='TVOC', type=None, unit='ppb', discard=False, canonical_variable=CanonicalVariable(name='total_volatile_organic_compounds', unit='ppb', desc=None)), InputColumn(name='equivalent_carbon_dioxide', key='eCO2', type=None, unit='ppm', discard=False, canonical_variable=CanonicalVariable(name='equivalent_carbon_dioxide', unit='ppm', desc=None)), InputColumn(name='ambient_light', key='Light', type=None, unit='lux', discard=False, canonical_variable=CanonicalVariable(name='ambient_light', unit='lux', desc=None)), InputColumn(name='noise_dB', key='Noise Level', type=None, unit='dB', discard=False, canonical_variable=CanonicalVariable(name='noise_dB', unit='dB', desc=None)), InputColumn(name='noise_dBA', key='Noise Level', type=None, unit='dBA', discard=False, canonical_variable=CanonicalVariable(name='noise_dBA', unit='dBA', desc=None)), InputColumn(name='air_pressure_near_surface', key='Barometric Pressure', type=None, unit='kPa', discard=False, canonical_variable=CanonicalVariable(name='air_pressure_near_surface', unit='Pa', desc=None)), InputColumn(name='nitrogen_oxide', key='NO2', type=None, unit='ppb', discard=False, canonical_variable=CanonicalVariable(name='nitrogen_oxide', unit='ppm', desc=None)), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='µg/m3', discard=False, canonical_variable=CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None)), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='ug/m3', discard=False, canonical_variable=CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None)), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='µg/m3', discard=False, canonical_variable=CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None)), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='ug/m3', discard=False, canonical_variable=CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None)), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='µg/m3', discard=False, canonical_variable=CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None)), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='ug/m3', discard=False, canonical_variable=CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None)), InputColumn(name='particulate_matter_particle_number_0_3', key='PN0.3', type=None, unit='#/0.1l', discard=False, canonical_variable=CanonicalVariable(name='particulate_ ...
# Aggregators
# TimeAggregator(5796e58b-81a7-4793-8d26-db5dda7dfc49, 1h, forwards)
# Actions
# CSVParser(metadata=MetaData(source_action_id=UUID('98cef1b2-a331-42b3-9f31-dcfdc2acf4e2'), state='parsed', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('98cef1b2-a331-42b3-9f31-dcfdc2acf4e2'), globals=Globals(canonical_variables=[CanonicalVariable(name='time', unit=None, desc='The time that the observation was made.'), CanonicalVariable(name='offset_tz', unit=None, desc='Uncertain what this means in the Meteotracker data.'), CanonicalVariable(name='lat', unit='°', desc='The lattitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='lon', unit='°', desc='The longitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='altitude', unit='m', desc='The altitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='author', unit=None, desc='The author field from the Meteotracker data'), CanonicalVariable(name='track_id', unit=None, desc='A unique identifer for a single recorded track from a mobile sensor.'), CanonicalVariable(name='station_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='created_at', unit=None, desc=None), CanonicalVariable(name='city', unit=None, desc=None), CanonicalVariable(name='country', unit=None, desc=None), CanonicalVariable(name='sensor_type', unit=None, desc=None), CanonicalVariable(name='location', unit=None, desc=None), CanonicalVariable(name='observation_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='air_temperature_near_surface', unit='K', desc=None), CanonicalVariable(name='relative_humidity_near_surface', unit='%', desc=None), CanonicalVariable(name='humidity_index', unit='K', desc=None), CanonicalVariable(name='internal_temperature', unit='K', desc='The internal temperature of the sensor.'), CanonicalVariable(name='vertical_temperature_gradient', unit='°C/100m', desc=None), CanonicalVariable(name='air_pressure_near_surface', unit='Pa', desc=None), CanonicalVariable(name='pressure_sealevel', unit='Pa', desc=None), CanonicalVariable(name='co2', unit='ppm', desc=None), CanonicalVariable(name='wind_gust', unit='m.s-1\xa0', desc=None), CanonicalVariable(name='wind_gust_direction', unit='°', desc=None), CanonicalVariable(name='dew_point_temperature', unit='K', desc=None), CanonicalVariable(name='wind_direction_near_surface', unit='°', desc=None), CanonicalVariable(name='wind_speed_near_surface', unit='m/s', desc=None), CanonicalVariable(name='rain', unit='mm', desc=None), CanonicalVariable(name='wind_direction', unit='Degrees', desc=None), CanonicalVariable(name='anemometer', unit='m/s', desc=None), CanonicalVariable(name='radiometer', unit='W/m^2', desc=None), CanonicalVariable(name='battery_level', unit='V', desc=None), CanonicalVariable(name='thermometer_min', unit='K', desc=None), CanonicalVariable(name='thermometer_max', unit='K', desc=None), CanonicalVariable(name='signal_strength', unit='CSQ', desc=None), CanonicalVariable(name='altitude', unit='m', desc=None), CanonicalVariable(name='solar_radiation_index', unit='1', desc=None), CanonicalVariable(name='bluetooth_RSSI', unit='dBm', desc=None), CanonicalVariable(name='carbon_dioxide', unit='ppm', desc=None), CanonicalVariable(name='carbon_monoxide', unit='ppm', desc=None), CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_4', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_3', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_5', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_1', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_p ...
#     "schemas": [
#         [
#             "class",
#             "expver",
#             "stream",
#             "date",
#             "time",
#             [
#                 "platform",
#                 [
#                     "observation_variable"
#                 ]
#             ]
#         ]
#     ],
#     "defaults": {}
# }, secrets={'headers': {'User-Agent': 'ECMWF IOT Scraper', 'From': 'thomas.hodson@ecmwf.int'}, 'ACRONET': {'client_id': 'webdrops', 'client_secret': '099803eb-08e5-4e4b-a3ca-70f13cfe1147', 'username': 'ichange.downloader', 'password': 'uD/lIhNLT7weDV98'}, 'MeteoTracker_API': {'email': 'thomas.hodson@ecmwf.int', 'password': 'Iiv3SY7vP8jLMaLY'}, 'polytope': {'user_email': 'thomas.hodson@ecmwf.int', 'user_key': '45fc8b2b2a894448d905420a151dccd6'}, 'breathe_london': {'api_key': 'a6f13cb4-b753-11ec-b909-0242ac120002'}, 'postgres_database': {'username': 'postgres', 'password': 'g7HEuiMHJTKczM4k'}}, api_hostname='http://localhost:5002/api/v1/', postgres_database={'host': 'localhost', 'port': 5432}, namespace='local_schema', actions={UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'): SmartCitizenKitSource(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), globals=..., finish_after=None, copy_metadata_to_columns=[InputColumn(name='sensor_name', key='sensor.name', type=None, unit=None, discard=False, canonical_variable=None)], cache_version=1, use_cache=True, cache_directory=PosixPath('/Users/math/git/IonBeam-Deployment/data/inputs/smart_citizen_kit'), value_columns=[InputColumn(name='total_volatile_organic_compounds', key='TVOC', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='equivalent_carbon_dioxide', key='eCO2', type=None, unit='ppm', discard=False, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='%', discard=True, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='lux', discard=False, canonical_variable=None), InputColumn(name='noise_dB', key='Noise Level', type=None, unit='dB', discard=False, canonical_variable=None), InputColumn(name='noise_dBA', key='Noise Level', type=None, unit='dBA', discard=False, canonical_variable=None), InputColumn(name='air_pressure_near_surface', key='Barometric Pressure', type=None, unit='kPa', discard=False, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='no2', type=None, unit='kOhm', discard=True, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='NO2', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='pv_panel', key='pv_panel', type=None, unit=None, discard=True, canonical_variable=None), InputColumn(name='pv_panel', key='pv panel', type=None, unit='V', discard=True, canonical_variable=None), InputColumn(name='nets', key='nets', type=None, unit='# networks', discard=True, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_3', key='PN0.3', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_5', key='PN0.5', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_1', key='PN1.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_10', key='PN10.0', type=None ...
# GenerateMetaData(metadata=MetaData(source_action_id=UUID('5796e58b-81a7-4793-8d26-db5dda7dfc49'), state='parsed', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('5796e58b-81a7-4793-8d26-db5dda7dfc49'), globals=Globals(canonical_variables=[CanonicalVariable(name='time', unit=None, desc='The time that the observation was made.'), CanonicalVariable(name='offset_tz', unit=None, desc='Uncertain what this means in the Meteotracker data.'), CanonicalVariable(name='lat', unit='°', desc='The lattitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='lon', unit='°', desc='The longitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='altitude', unit='m', desc='The altitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='author', unit=None, desc='The author field from the Meteotracker data'), CanonicalVariable(name='track_id', unit=None, desc='A unique identifer for a single recorded track from a mobile sensor.'), CanonicalVariable(name='station_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='created_at', unit=None, desc=None), CanonicalVariable(name='city', unit=None, desc=None), CanonicalVariable(name='country', unit=None, desc=None), CanonicalVariable(name='sensor_type', unit=None, desc=None), CanonicalVariable(name='location', unit=None, desc=None), CanonicalVariable(name='observation_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='air_temperature_near_surface', unit='K', desc=None), CanonicalVariable(name='relative_humidity_near_surface', unit='%', desc=None), CanonicalVariable(name='humidity_index', unit='K', desc=None), CanonicalVariable(name='internal_temperature', unit='K', desc='The internal temperature of the sensor.'), CanonicalVariable(name='vertical_temperature_gradient', unit='°C/100m', desc=None), CanonicalVariable(name='air_pressure_near_surface', unit='Pa', desc=None), CanonicalVariable(name='pressure_sealevel', unit='Pa', desc=None), CanonicalVariable(name='co2', unit='ppm', desc=None), CanonicalVariable(name='wind_gust', unit='m.s-1\xa0', desc=None), CanonicalVariable(name='wind_gust_direction', unit='°', desc=None), CanonicalVariable(name='dew_point_temperature', unit='K', desc=None), CanonicalVariable(name='wind_direction_near_surface', unit='°', desc=None), CanonicalVariable(name='wind_speed_near_surface', unit='m/s', desc=None), CanonicalVariable(name='rain', unit='mm', desc=None), CanonicalVariable(name='wind_direction', unit='Degrees', desc=None), CanonicalVariable(name='anemometer', unit='m/s', desc=None), CanonicalVariable(name='radiometer', unit='W/m^2', desc=None), CanonicalVariable(name='battery_level', unit='V', desc=None), CanonicalVariable(name='thermometer_min', unit='K', desc=None), CanonicalVariable(name='thermometer_max', unit='K', desc=None), CanonicalVariable(name='signal_strength', unit='CSQ', desc=None), CanonicalVariable(name='altitude', unit='m', desc=None), CanonicalVariable(name='solar_radiation_index', unit='1', desc=None), CanonicalVariable(name='bluetooth_RSSI', unit='dBm', desc=None), CanonicalVariable(name='carbon_dioxide', unit='ppm', desc=None), CanonicalVariable(name='carbon_monoxide', unit='ppm', desc=None), CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_4', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_3', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_5', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_1', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_m ...
#     "schemas": [
#         [
#             "class",
#             "expver",
#             "stream",
#             "date",
#             "time",
#             [
#                 "platform",
#                 [
#                     "observation_variable"
#                 ]
#             ]
#         ]
#     ],
#     "defaults": {}
# }, secrets={'headers': {'User-Agent': 'ECMWF IOT Scraper', 'From': 'thomas.hodson@ecmwf.int'}, 'ACRONET': {'client_id': 'webdrops', 'client_secret': '099803eb-08e5-4e4b-a3ca-70f13cfe1147', 'username': 'ichange.downloader', 'password': 'uD/lIhNLT7weDV98'}, 'MeteoTracker_API': {'email': 'thomas.hodson@ecmwf.int', 'password': 'Iiv3SY7vP8jLMaLY'}, 'polytope': {'user_email': 'thomas.hodson@ecmwf.int', 'user_key': '45fc8b2b2a894448d905420a151dccd6'}, 'breathe_london': {'api_key': 'a6f13cb4-b753-11ec-b909-0242ac120002'}, 'postgres_database': {'username': 'postgres', 'password': 'g7HEuiMHJTKczM4k'}}, api_hostname='http://localhost:5002/api/v1/', postgres_database={'host': 'localhost', 'port': 5432}, namespace='local_schema', actions={UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'): SmartCitizenKitSource(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), globals=..., finish_after=None, copy_metadata_to_columns=[InputColumn(name='sensor_name', key='sensor.name', type=None, unit=None, discard=False, canonical_variable=None)], cache_version=1, use_cache=True, cache_directory=PosixPath('/Users/math/git/IonBeam-Deployment/data/inputs/smart_citizen_kit'), value_columns=[InputColumn(name='total_volatile_organic_compounds', key='TVOC', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='equivalent_carbon_dioxide', key='eCO2', type=None, unit='ppm', discard=False, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='%', discard=True, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='lux', discard=False, canonical_variable=None), InputColumn(name='noise_dB', key='Noise Level', type=None, unit='dB', discard=False, canonical_variable=None), InputColumn(name='noise_dBA', key='Noise Level', type=None, unit='dBA', discard=False, canonical_variable=None), InputColumn(name='air_pressure_near_surface', key='Barometric Pressure', type=None, unit='kPa', discard=False, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='no2', type=None, unit='kOhm', discard=True, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='NO2', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='pv_panel', key='pv_panel', type=None, unit=None, discard=True, canonical_variable=None), InputColumn(name='pv_panel', key='pv panel', type=None, unit='V', discard=True, canonical_variable=None), InputColumn(name='nets', key='nets', type=None, unit='# networks', discard=True, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_3', key='PN0.3', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_5', key='PN0.5', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_1', key='PN1.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_10', key='PN10.0', type=None ...
# ODCEncoder(metadata=MetaData(source_action_id=UUID('887b49b7-5bc2-44f0-92fe-5aa8759bf08c'), state='odc_encoded', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('887b49b7-5bc2-44f0-92fe-5aa8759bf08c'), globals=Globals(canonical_variables=[CanonicalVariable(name='time', unit=None, desc='The time that the observation was made.'), CanonicalVariable(name='offset_tz', unit=None, desc='Uncertain what this means in the Meteotracker data.'), CanonicalVariable(name='lat', unit='°', desc='The lattitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='lon', unit='°', desc='The longitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='altitude', unit='m', desc='The altitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='author', unit=None, desc='The author field from the Meteotracker data'), CanonicalVariable(name='track_id', unit=None, desc='A unique identifer for a single recorded track from a mobile sensor.'), CanonicalVariable(name='station_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='created_at', unit=None, desc=None), CanonicalVariable(name='city', unit=None, desc=None), CanonicalVariable(name='country', unit=None, desc=None), CanonicalVariable(name='sensor_type', unit=None, desc=None), CanonicalVariable(name='location', unit=None, desc=None), CanonicalVariable(name='observation_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='air_temperature_near_surface', unit='K', desc=None), CanonicalVariable(name='relative_humidity_near_surface', unit='%', desc=None), CanonicalVariable(name='humidity_index', unit='K', desc=None), CanonicalVariable(name='internal_temperature', unit='K', desc='The internal temperature of the sensor.'), CanonicalVariable(name='vertical_temperature_gradient', unit='°C/100m', desc=None), CanonicalVariable(name='air_pressure_near_surface', unit='Pa', desc=None), CanonicalVariable(name='pressure_sealevel', unit='Pa', desc=None), CanonicalVariable(name='co2', unit='ppm', desc=None), CanonicalVariable(name='wind_gust', unit='m.s-1\xa0', desc=None), CanonicalVariable(name='wind_gust_direction', unit='°', desc=None), CanonicalVariable(name='dew_point_temperature', unit='K', desc=None), CanonicalVariable(name='wind_direction_near_surface', unit='°', desc=None), CanonicalVariable(name='wind_speed_near_surface', unit='m/s', desc=None), CanonicalVariable(name='rain', unit='mm', desc=None), CanonicalVariable(name='wind_direction', unit='Degrees', desc=None), CanonicalVariable(name='anemometer', unit='m/s', desc=None), CanonicalVariable(name='radiometer', unit='W/m^2', desc=None), CanonicalVariable(name='battery_level', unit='V', desc=None), CanonicalVariable(name='thermometer_min', unit='K', desc=None), CanonicalVariable(name='thermometer_max', unit='K', desc=None), CanonicalVariable(name='signal_strength', unit='CSQ', desc=None), CanonicalVariable(name='altitude', unit='m', desc=None), CanonicalVariable(name='solar_radiation_index', unit='1', desc=None), CanonicalVariable(name='bluetooth_RSSI', unit='dBm', desc=None), CanonicalVariable(name='carbon_dioxide', unit='ppm', desc=None), CanonicalVariable(name='carbon_monoxide', unit='ppm', desc=None), CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_4', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_3', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_5', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_1', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_ma ...
#     "schemas": [
#         [
#             "class",
#             "expver",
#             "stream",
#             "date",
#             "time",
#             [
#                 "platform",
#                 [
#                     "observation_variable"
#                 ]
#             ]
#         ]
#     ],
#     "defaults": {}
# }, secrets={'headers': {'User-Agent': 'ECMWF IOT Scraper', 'From': 'thomas.hodson@ecmwf.int'}, 'ACRONET': {'client_id': 'webdrops', 'client_secret': '099803eb-08e5-4e4b-a3ca-70f13cfe1147', 'username': 'ichange.downloader', 'password': 'uD/lIhNLT7weDV98'}, 'MeteoTracker_API': {'email': 'thomas.hodson@ecmwf.int', 'password': 'Iiv3SY7vP8jLMaLY'}, 'polytope': {'user_email': 'thomas.hodson@ecmwf.int', 'user_key': '45fc8b2b2a894448d905420a151dccd6'}, 'breathe_london': {'api_key': 'a6f13cb4-b753-11ec-b909-0242ac120002'}, 'postgres_database': {'username': 'postgres', 'password': 'g7HEuiMHJTKczM4k'}}, api_hostname='http://localhost:5002/api/v1/', postgres_database={'host': 'localhost', 'port': 5432}, namespace='local_schema', actions={UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'): SmartCitizenKitSource(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), globals=..., finish_after=None, copy_metadata_to_columns=[InputColumn(name='sensor_name', key='sensor.name', type=None, unit=None, discard=False, canonical_variable=None)], cache_version=1, use_cache=True, cache_directory=PosixPath('/Users/math/git/IonBeam-Deployment/data/inputs/smart_citizen_kit'), value_columns=[InputColumn(name='total_volatile_organic_compounds', key='TVOC', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='equivalent_carbon_dioxide', key='eCO2', type=None, unit='ppm', discard=False, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='%', discard=True, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='lux', discard=False, canonical_variable=None), InputColumn(name='noise_dB', key='Noise Level', type=None, unit='dB', discard=False, canonical_variable=None), InputColumn(name='noise_dBA', key='Noise Level', type=None, unit='dBA', discard=False, canonical_variable=None), InputColumn(name='air_pressure_near_surface', key='Barometric Pressure', type=None, unit='kPa', discard=False, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='no2', type=None, unit='kOhm', discard=True, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='NO2', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='pv_panel', key='pv_panel', type=None, unit=None, discard=True, canonical_variable=None), InputColumn(name='pv_panel', key='pv panel', type=None, unit='V', discard=True, canonical_variable=None), InputColumn(name='nets', key='nets', type=None, unit='# networks', discard=True, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_3', key='PN0.3', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_5', key='PN0.5', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_1', key='PN1.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_10', key='PN10.0', type=None ...
# RESTWriter(metadata=MetaData(source_action_id=UUID('b4ba8f19-9878-4820-8e79-7c3109ccfc3a'), state='written', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('b4ba8f19-9878-4820-8e79-7c3109ccfc3a'), globals=Globals(canonical_variables=[CanonicalVariable(name='time', unit=None, desc='The time that the observation was made.'), CanonicalVariable(name='offset_tz', unit=None, desc='Uncertain what this means in the Meteotracker data.'), CanonicalVariable(name='lat', unit='°', desc='The lattitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='lon', unit='°', desc='The longitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='altitude', unit='m', desc='The altitude of the observation, referenced to WGS84 (EPSG: 4326)'), CanonicalVariable(name='author', unit=None, desc='The author field from the Meteotracker data'), CanonicalVariable(name='track_id', unit=None, desc='A unique identifer for a single recorded track from a mobile sensor.'), CanonicalVariable(name='station_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='created_at', unit=None, desc=None), CanonicalVariable(name='city', unit=None, desc=None), CanonicalVariable(name='country', unit=None, desc=None), CanonicalVariable(name='sensor_type', unit=None, desc=None), CanonicalVariable(name='location', unit=None, desc=None), CanonicalVariable(name='observation_id', unit=None, desc='A unique identifer for a stationary sensor.'), CanonicalVariable(name='air_temperature_near_surface', unit='K', desc=None), CanonicalVariable(name='relative_humidity_near_surface', unit='%', desc=None), CanonicalVariable(name='humidity_index', unit='K', desc=None), CanonicalVariable(name='internal_temperature', unit='K', desc='The internal temperature of the sensor.'), CanonicalVariable(name='vertical_temperature_gradient', unit='°C/100m', desc=None), CanonicalVariable(name='air_pressure_near_surface', unit='Pa', desc=None), CanonicalVariable(name='pressure_sealevel', unit='Pa', desc=None), CanonicalVariable(name='co2', unit='ppm', desc=None), CanonicalVariable(name='wind_gust', unit='m.s-1\xa0', desc=None), CanonicalVariable(name='wind_gust_direction', unit='°', desc=None), CanonicalVariable(name='dew_point_temperature', unit='K', desc=None), CanonicalVariable(name='wind_direction_near_surface', unit='°', desc=None), CanonicalVariable(name='wind_speed_near_surface', unit='m/s', desc=None), CanonicalVariable(name='rain', unit='mm', desc=None), CanonicalVariable(name='wind_direction', unit='Degrees', desc=None), CanonicalVariable(name='anemometer', unit='m/s', desc=None), CanonicalVariable(name='radiometer', unit='W/m^2', desc=None), CanonicalVariable(name='battery_level', unit='V', desc=None), CanonicalVariable(name='thermometer_min', unit='K', desc=None), CanonicalVariable(name='thermometer_max', unit='K', desc=None), CanonicalVariable(name='signal_strength', unit='CSQ', desc=None), CanonicalVariable(name='altitude', unit='m', desc=None), CanonicalVariable(name='solar_radiation_index', unit='1', desc=None), CanonicalVariable(name='bluetooth_RSSI', unit='dBm', desc=None), CanonicalVariable(name='carbon_dioxide', unit='ppm', desc=None), CanonicalVariable(name='carbon_monoxide', unit='ppm', desc=None), CanonicalVariable(name='particulate_matter_1', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_2_5', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_4', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_10', unit='μg/m3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_3', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_0_5', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter_particle_number_1', unit='#/cm3', desc=None), CanonicalVariable(name='particulate_matter ...
#     "schemas": [
#         [
#             "class",
#             "expver",
#             "stream",
#             "date",
#             "time",
#             [
#                 "platform",
#                 [
#                     "observation_variable"
#                 ]
#             ]
#         ]
#     ],
#     "defaults": {}
# }, secrets={'headers': {'User-Agent': 'ECMWF IOT Scraper', 'From': 'thomas.hodson@ecmwf.int'}, 'ACRONET': {'client_id': 'webdrops', 'client_secret': '099803eb-08e5-4e4b-a3ca-70f13cfe1147', 'username': 'ichange.downloader', 'password': 'uD/lIhNLT7weDV98'}, 'MeteoTracker_API': {'email': 'thomas.hodson@ecmwf.int', 'password': 'Iiv3SY7vP8jLMaLY'}, 'polytope': {'user_email': 'thomas.hodson@ecmwf.int', 'user_key': '45fc8b2b2a894448d905420a151dccd6'}, 'breathe_london': {'api_key': 'a6f13cb4-b753-11ec-b909-0242ac120002'}, 'postgres_database': {'username': 'postgres', 'password': 'g7HEuiMHJTKczM4k'}}, api_hostname='http://localhost:5002/api/v1/', postgres_database={'host': 'localhost', 'port': 5432}, namespace='local_schema', actions={UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'): SmartCitizenKitSource(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={}), id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), globals=..., finish_after=None, copy_metadata_to_columns=[InputColumn(name='sensor_name', key='sensor.name', type=None, unit=None, discard=False, canonical_variable=None)], cache_version=1, use_cache=True, cache_directory=PosixPath('/Users/math/git/IonBeam-Deployment/data/inputs/smart_citizen_kit'), value_columns=[InputColumn(name='total_volatile_organic_compounds', key='TVOC', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='equivalent_carbon_dioxide', key='eCO2', type=None, unit='ppm', discard=False, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='%', discard=True, canonical_variable=None), InputColumn(name='ambient_light', key='Light', type=None, unit='lux', discard=False, canonical_variable=None), InputColumn(name='noise_dB', key='Noise Level', type=None, unit='dB', discard=False, canonical_variable=None), InputColumn(name='noise_dBA', key='Noise Level', type=None, unit='dBA', discard=False, canonical_variable=None), InputColumn(name='air_pressure_near_surface', key='Barometric Pressure', type=None, unit='kPa', discard=False, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='no2', type=None, unit='kOhm', discard=True, canonical_variable=None), InputColumn(name='nitrogen_oxide', key='NO2', type=None, unit='ppb', discard=False, canonical_variable=None), InputColumn(name='pv_panel', key='pv_panel', type=None, unit=None, discard=True, canonical_variable=None), InputColumn(name='pv_panel', key='pv panel', type=None, unit='V', discard=True, canonical_variable=None), InputColumn(name='nets', key='nets', type=None, unit='# networks', discard=True, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='µg/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='ug/m3', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_3', key='PN0.3', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_0_5', key='PN0.5', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_1', key='PN1.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None), InputColumn(name='particulate_matter_particle_number_10', key='PN10.0', type=None ...

# %%
sck_source = actions[0]
sck_source.value_columns
# Out:
# [InputColumn(name='total_volatile_organic_compounds', key='TVOC', type=None, unit='ppb', discard=False, canonical_variable=None),
#  InputColumn(name='equivalent_carbon_dioxide', key='eCO2', type=None, unit='ppm', discard=False, canonical_variable=None),
#  InputColumn(name='ambient_light', key='Light', type=None, unit='%', discard=True, canonical_variable=None),
#  InputColumn(name='ambient_light', key='Light', type=None, unit='lux', discard=False, canonical_variable=None),
#  InputColumn(name='noise_dB', key='Noise Level', type=None, unit='dB', discard=False, canonical_variable=None),
#  InputColumn(name='noise_dBA', key='Noise Level', type=None, unit='dBA', discard=False, canonical_variable=None),
#  InputColumn(name='air_pressure_near_surface', key='Barometric Pressure', type=None, unit='kPa', discard=False, canonical_variable=None),
#  InputColumn(name='nitrogen_oxide', key='no2', type=None, unit='kOhm', discard=True, canonical_variable=None),
#  InputColumn(name='nitrogen_oxide', key='NO2', type=None, unit='ppb', discard=False, canonical_variable=None),
#  InputColumn(name='pv_panel', key='pv_panel', type=None, unit=None, discard=True, canonical_variable=None),
#  InputColumn(name='pv_panel', key='pv panel', type=None, unit='V', discard=True, canonical_variable=None),
#  InputColumn(name='nets', key='nets', type=None, unit='# networks', discard=True, canonical_variable=None),
#  InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='µg/m3', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_1', key='PM 1', type=None, unit='ug/m3', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='µg/m3', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_10', key='PM 10', type=None, unit='ug/m3', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='µg/m3', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_2_5', key='PM 2.5', type=None, unit='ug/m3', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_0_3', key='PN0.3', type=None, unit='#/0.1l', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_0_5', key='PN0.5', type=None, unit='#/0.1l', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_1', key='PN1.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_10', key='PN10.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_2_5', key='PN2.5', type=None, unit='#/0.1l', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_5', key='PN5.0', type=None, unit='#/0.1l', discard=False, canonical_variable=None),
#  InputColumn(name='particulate_matter_particle_number_5', key='PN5.0', type=None, unit='#/0.1L', discard=False, canonical_variable=None),
#  InputColumn(name='carbon_dioxide', key='CO2', type=None, unit='ppm', discard=False, canonical_variable=None),
#  InputColumn(name='carbon_monoxide', key='co', type=None, unit='kOhm', discard=True, canonical_variable=None),
#  InputColumn(name='ozone', key='O3', type=None, unit='ppb', discard=False, canonical_variable=None),
#  InputColumn(name='relative_humidity_near_surface', key='Relative Humidity', type=None, unit='%', discard=False, canonical_variable=None),
#  InputColumn(name='air_temperature_near_surface', key='Air Temperature', type=None, unit='ºC', discard=False, canonical_variable=None),
#  InputColumn(name='battery_voltage', key='battery', type=None, unit='%', discard=True, canonical_variable=None),
#  InputColumn(name='battery_voltage', key='Voltage', type=None, unit='V', discard=True, canonical_variable=None)]

# %%
import json
devices = sck_source.get_ICHANGE_devices()
print(json.dumps(devices[0], indent = 4))
# Out:
# {
#     "id": 28,
#     "uuid": "856e9670-03d1-481e-b9c5-6bf16474d993",
#     "name": "Manyi_08230",
#     "description": "Desde el 3/5/13: en exterior.\nEmplazamiento: Zona arbolada en limite de Parque Natural Sant Lloren\u00e7.\nSituado a unos 60m de la calle con trafico mas pr\u00f3xima.\n\nColocaci\u00f3n sensor: desde ahora; 2/4/14 en caja kit.\nSituado bajo placa solar.\n\nAlimentaci\u00f3n del sensor: Desde el 19/05/2013, conectado a placa solar de 12V-610mA Ref: ET-M53610 encarada a 182 Sur, con unos 45grados de inclinaci\u00f3n. Desde 2/4/14, sin placa solar, alimentado permanente con alimentador.",
#     "state": "has_published",
#     "system_tags": [
#         "offline",
#         "outdoor"
#     ],
#     "user_tags": [
#         "Barcelona"
#     ],
#     "last_reading_at": "2014-04-04T18:30:16Z",
#     "created_at": "2013-04-24T22:17:56Z",
#     "updated_at": "2024-06-27T17:03:14Z",
#     "notify": {
#         "stopped_publishing": false,
#         "low_battery": false
#     },
#     "device_token": "[FILTERED]",
#     "postprocessing": null,
#     "location": {
#         "ip": null,
#         "exposure": "outdoor",
#         "elevation": 680,
#         "latitude": 41.61441,
#         "longitude": 2.01106,
#         "geohash": "sp3ktz8mt0",
#         "city": "Matadepera",
#         "country_code": "ES",
#         "country": "Spain"
#     },
#     "data_policy": {
#         "is_private": "[FILTERED]",
#         "enable_forwarding": "[FILTERED]",
#         "precise_location": "[FILTERED]"
#     },
#     "hardware": {
#         "name": "SmartCitizen Kit 1.0",
#         "type": "SCK",
#         "version": "1.0",
#         "slug": "sck:1,0",
#         "last_status_message": "[FILTERED]"
#     },
#     "owner": {
#         "id": 12,
#         "uuid": "7ff5b84c-1f20-4ae4-a7f9-c588ebf51161",
#         "username": "sejarque",
#         "url": "",
#         "avatar": "https://images.smartcitizen.me/s100/avatars/12-Yo.JPG",
#         "profile_picture": "https://api.smartcitizen.me/rails/active_storage/blobs/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBalVCIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--cb535c26e1ee4311479135fc16f1752d7bea5f9d/12-Yo.JPG",
#         "location": {
#             "city": "MATADEPERA",
#             "country": null,
#             "country_code": null
#         },
#         "device_ids": [
#             28
#         ]
#     },
#     "data": {
#         "sensors": [
#             {
#                 "id": 10,
#                 "ancestry": null,
#                 "name": "Battery SCK",
#                 "description": "Custom Circuit",
#                 "unit": "%",
#                 "created_at": "2015-02-02T18:18:00Z",
#                 "updated_at": "2020-12-11T16:12:40Z",
#                 "uuid": "c9ff2784-53a7-4a84-b0fc-90ecc7e313f9",
#                 "default_key": "bat",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 7,
#                     "name": "battery",
#                     "description": "The SCK remaining battery level in percentage.",
#                     "unit": null,
#                     "uuid": "c5964926-c2d2-4714-98b5-18f84c6f95c1",
#                     "definition": null
#                 },
#                 "value": 71.7,
#                 "prev_value": 71.7,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 5,
#                 "ancestry": "3",
#                 "name": "DHT22 - Humidity",
#                 "description": "Humidity",
#                 "unit": "%",
#                 "created_at": "2015-02-02T18:15:34Z",
#                 "updated_at": "2015-09-17T14:56:59Z",
#                 "uuid": "6b4b64d9-3841-446c-a7f5-63f480932b96",
#                 "default_key": "hum",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 2,
#                     "name": "Relative Humidity",
#                     "description": "Relative humidity is a measure of the amount of moisture in the air relative to the total amount of moisture the air can hold. For instance, if the relative humidity was 50%, then the air is only half saturated with moisture.",
#                     "unit": null,
#                     "uuid": "9cbbd396-5bd3-44be-adc0-7ffba778072d",
#                     "definition": null
#                 },
#                 "value": 35.6,
#                 "prev_value": 35.6,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 4,
#                 "ancestry": "3",
#                 "name": "DHT22 - Temperature",
#                 "description": "Temperature",
#                 "unit": "\u00baC",
#                 "created_at": "2015-02-02T18:15:14Z",
#                 "updated_at": "2015-09-17T14:52:11Z",
#                 "uuid": "a50dbd88-b0c7-4094-ad74-2b755e8023a8",
#                 "default_key": "temp",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 1,
#                     "name": "Air Temperature",
#                     "description": "Air temperature is a measure of how hot or cold the air is. It is the most commonly measured weather parameter. Air temperature is dependent on the amount and strength of the sunlight hitting the earth, and atmospheric conditions, such as cloud cover and humidity, which trap heat.",
#                     "unit": null,
#                     "uuid": "b3f44b63-0a17-4d84-bbf1-4c17764b7eae",
#                     "definition": null
#                 },
#                 "value": 24.5,
#                 "prev_value": 24.5,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 8,
#                 "ancestry": null,
#                 "name": "MICS-2710",
#                 "description": "MOS NO2 gas sensor",
#                 "unit": "kOhm",
#                 "created_at": "2015-02-02T18:17:23Z",
#                 "updated_at": "2015-09-16T16:50:41Z",
#                 "uuid": "1eb0249d-29d8-41be-8e24-d3b1e5773c0f",
#                 "default_key": "no2",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 6,
#                     "name": "no2",
#                     "description": "Nitrogen dioxide is a toxic gas. It is a pollutant in some urban areas due the excess air required for complete combustion of fuels introduces nitrogen into the combustion of internal combustion engines (cars, trucks, ships...) and power stations. \u26a0 Note: values are offered in RS (sensor resistance in kOhm) as a relative measurement from the R0 (sensor zero resistance). Due to sensor intra-model variability we recommend using this as a relative measurement within the same kit readings.",
#                     "unit": null,
#                     "uuid": "2ca7194a-f4b4-4b55-916b-debb84f33fbd",
#                     "definition": null
#                 },
#                 "value": 13.766,
#                 "prev_value": 13.766,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 9,
#                 "ancestry": null,
#                 "name": "MICS-5525",
#                 "description": "MOS CO gas sensor",
#                 "unit": "kOhm",
#                 "created_at": "2015-02-02T18:17:44Z",
#                 "updated_at": "2015-09-16T16:51:42Z",
#                 "uuid": "7baaecb7-2586-4063-9c15-bfa999e329aa",
#                 "default_key": "co",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 5,
#                     "name": "co",
#                     "description": "Carbon monoxide is a colorless, odorless, and tasteless gas. It is a pollutant in some urban areas coming from the exhaust of internal combustion engines  (cars, trucks, ships...)  and incomplete combustion of various other fuels. \u26a0 Note: values are offered in RS (sensor resistance in kOhm) as a relative measurement from the R0 (sensor zero resistance), we approximate R0 at 75kOhm.",
#                     "unit": null,
#                     "uuid": "fd22c946-d6d8-40c3-97ea-0021ce6d21a1",
#                     "definition": null
#                 },
#                 "value": 125.246,
#                 "prev_value": 125.246,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 21,
#                 "ancestry": null,
#                 "name": "Microchip RN-131",
#                 "description": "802.11 b/g WiFi",
#                 "unit": "# networks",
#                 "created_at": "2015-05-04T11:17:18Z",
#                 "updated_at": "2015-07-05T19:57:22Z",
#                 "uuid": "5b1f0e38-336a-4abf-9989-69b48f0026ef",
#                 "default_key": "nets",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 9,
#                     "name": "nets",
#                     "description": "The amount of Wi-Fi networks visible by the SCK.",
#                     "unit": null,
#                     "uuid": "c3ea53a8-8235-4d0c-84ee-729e6ade589c",
#                     "definition": null
#                 },
#                 "value": 2.0,
#                 "prev_value": 2.0,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 7,
#                 "ancestry": null,
#                 "name": "POM-3044P-R",
#                 "description": "Electret microphone with envelope follower sound pressure sensor (noise)",
#                 "unit": "dB",
#                 "created_at": "2015-02-02T18:16:41Z",
#                 "updated_at": "2015-09-17T14:56:00Z",
#                 "uuid": "5efd2376-6783-476b-bf85-57ead5f89654",
#                 "default_key": "noise",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 4,
#                     "name": "Noise Level",
#                     "description": "dB's measure sound pressure difference between the average local pressure and the pressure in the sound wave.  A quiet library is below 40dB, your house is around 50dB and a diesel truck in your street 90dB.",
#                     "unit": null,
#                     "uuid": "2841719f-658e-40df-a14a-74a86adc1410",
#                     "definition": null
#                 },
#                 "value": 77.0,
#                 "prev_value": 77.0,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 6,
#                 "ancestry": null,
#                 "name": "PVD-P8001",
#                 "description": "LDR Analog Light Sensor",
#                 "unit": "%",
#                 "created_at": "2015-02-02T18:15:55Z",
#                 "updated_at": "2015-09-17T14:57:28Z",
#                 "uuid": "0e9cdc5b-d369-4480-9676-bf31af6a5977",
#                 "default_key": "light",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 3,
#                     "name": "Light",
#                     "description": "Lux is a measure of how much light is spread over a given area. A full moon clear night is around 1 lux, inside an office building you usually have 400 lux and a bright day can be more than 20000 lux.",
#                     "unit": null,
#                     "uuid": "50aa0431-86ac-4340-bf51-ad498ee35a3b",
#                     "definition": null
#                 },
#                 "value": 0.0,
#                 "prev_value": 0.0,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             },
#             {
#                 "id": 11,
#                 "ancestry": null,
#                 "name": "Solar Panel",
#                 "description": "Custom Circuit",
#                 "unit": "V",
#                 "created_at": "2015-02-02T18:18:12Z",
#                 "updated_at": "2015-09-17T14:58:07Z",
#                 "uuid": "4ab402c5-9297-407a-b0b2-7089520f7ed0",
#                 "default_key": "panel",
#                 "datasheet": null,
#                 "unit_definition": null,
#                 "measurement": {
#                     "id": 8,
#                     "name": "pv panel",
#                     "description": "The SCK's solar panel energy voltage (when connected).",
#                     "unit": null,
#                     "uuid": "68cf6255-9b17-4002-9fe0-736267050b74",
#                     "definition": null
#                 },
#                 "value": 4.638,
#                 "prev_value": 4.638,
#                 "last_reading_at": "2014-04-04T18:30:16Z",
#                 "tags": []
#             }
#         ]
#     }
# }

# %%
devices[0]["data"]["sensors"][0]
# Out:
# {'id': 10,
#  'ancestry': None,
#  'name': 'Battery SCK',
#  'description': 'Custom Circuit',
#  'unit': '%',
#  'created_at': '2015-02-02T18:18:00Z',
#  'updated_at': '2020-12-11T16:12:40Z',
#  'uuid': 'c9ff2784-53a7-4a84-b0fc-90ecc7e313f9',
#  'default_key': 'bat',
#  'datasheet': None,
#  'unit_definition': None,
#  'measurement': {'id': 7,
#   'name': 'battery',
#   'description': 'The SCK remaining battery level in percentage.',
#   'unit': None,
#   'uuid': 'c5964926-c2d2-4714-98b5-18f84c6f95c1',
#   'definition': None},
#  'value': 71.7,
#  'prev_value': 71.7,
#  'last_reading_at': '2014-04-04T18:30:16Z',
#  'tags': []}

# %%
from ionbeam.metadata.db import init_db

init_db(config.globals)
# Out:
# WARNING:ionbeam.metadata.db:Creating Postgres schema local_schema if it doesn't exist
# WARNING:ionbeam.metadata.db:Deleting all SQL tables in schema local_schema
# WARNING:ionbeam.metadata.db:Recreating all SQL tables
# WARNING:ionbeam.metadata.db:Populating properties from the config
# INFO:ionbeam.metadata.db:Adding 'Sensor.Community' to Authors table
# INFO:ionbeam.metadata.db:Adding 'Meteotracker' to Authors table
# INFO:ionbeam.metadata.db:Adding 'Acronet' to Authors table
# INFO:ionbeam.metadata.db:Adding 'SmartCitizenKit' to Authors table

# %%
from ionbeam.metadata import db
from shapely.geometry import Point

from ionbeam.sources.smart_citizen_kit.metadata import construct_sck_metadata

device = devices[0]
construct_sck_metadata(sck_source, device)

# %%
from sqlalchemy.orm import Session
device = devices[0]
id = device["id"]


with Session(sck_source.globals.sql_engine) as session:
    stations = session.query(db.Station).all()
    station = stations[0]
    print("Retrieved station: ", station)
    j = station.as_json()
    print(station)
    print(station.sensors[1])
    print(station.sensors[1].properties)

print(json.dumps(j, indent = 4))
# Out:
# Retrieved station:  Station(id=9fe29acc-9b47-460e-a958-b23695e2e3af, external_id='28')
# Station(id=9fe29acc-9b47-460e-a958-b23695e2e3af, external_id='28')
# Sensor(id=2, name='POM-3044P-R')
# [Property(key='noise_dB', name='noise_dB', unit='dB', description=None)]
# {
#     "name": "Manyi_08230",
#     "description": "Desde el 3/5/13: en exterior.\nEmplazamiento: Zona arbolada en limite de Parque Natural Sant Lloren\u00e7.\nSituado a unos 60m de la calle con trafico mas pr\u00f3xima.\n\nColocaci\u00f3n sensor: desde ahora; 2/4/14 en caja kit.\nSituado bajo placa solar.\n\nAlimentaci\u00f3n del sensor: Desde el 19/05/2013, conectado a placa solar de 12V-610mA Ref: ET-M53610 encarada a 182 Sur, con unos 45grados de inclinaci\u00f3n. Desde 2/4/14, sin placa solar, alimentado permanente con alimentador.",
#     "platform": "Smart Citizen Kit",
#     "external_id": "28",
#     "location": [
#         2.01106,
#         41.61441
#     ],
#     "geojson": {
#         "type": "Point",
#         "coordinates": [
#             2.01106,
#             41.61441
#         ],
#         "bbox": [
#             2.01106,
#             41.61441,
#             2.01106,
#             41.61441
#         ]
#     },
#     "time_span": [
#         "2013-04-24T22:17:56Z",
#         "2014-04-04T18:30:16Z"
#     ],
#     "authors": [],
#     "sensors": [
#         {
#             "name": "DHT22",
#             "description": "A digital temperature and humidity sensor. It uses a capacitive humidity sensor and a thermistor to measure the surrounding air, and spits out a digital signal on the data pin (no analog input pins needed)",
#             "url": "",
#             "properties": [
#                 {
#                     "key": "air_temperature_near_surface",
#                     "name": "air_temperature_near_surface",
#                     "unit": "K",
#                     "description": null,
#                     "url": ""
#                 },
#                 {
#                     "key": "relative_humidity_near_surface",
#                     "name": "relative_humidity_near_surface",
#                     "unit": "%",
#                     "description": null,
#                     "url": ""
#                 }
#             ]
#         },
#         {
#             "name": "POM-3044P-R",
#             "description": "Electret microphone with envelope follower sound pressure sensor (noise)",
#             "url": "",
#             "properties": [
#                 {
#                     "key": "noise_dB",
#                     "name": "noise_dB",
#                     "unit": "dB",
#                     "description": null,
#                     "url": ""
#                 }
#             ]
#         }
#     ]
# }

# %%
for device in devices:
    construct_sck_metadata(sck_source, device)
# Out:
# WARNING:ionbeam.sources.smart_citizen_kit.metadata:Skipping device 59 as it has no last_reading_at = None
# WARNING:ionbeam.sources.smart_citizen_kit.metadata:Skipping device 91 as it has no last_reading_at = None
# WARNING:ionbeam.sources.smart_citizen_kit.metadata:Skipping device 140 as it has no last_reading_at = None

# %%
online = True
if online:
    source = sources[0]
    source.globals.offline = !online
    source.use_cache = False
    incoming_message_stream = source.generate()
    message = next(incoming_message_stream)
    message
else:
    p = Path('/Users/math/git/IonBeam-Deployment/data/inputs/meteotracker/MeteoTracker_62ae154f1d8e11061d4474b2.csv')
    message = FileMessage(
        metadata=MetaData(state='raw',
            source='meteotracker',
            filepath= p,
            variables = list(pd.read_csv(p).columns),             
            ))
message
# Out:
# TabularMessage(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={'device_id': 15496, 'sensor_key': 'tvoc', 'sensor_id': 113, 'component_id': 72773, 'rollup': '1s', 'function': 'avg', 'from': '2023-06-10T00:00:00Z', 'to': '2025-05-01T00:00:00Z', 'sample_size': 269948, 'device': {'id': 15496, 'uuid': 'a34e7c58-d235-432c-88b6-9d3bb48d0288', 'name': 'HoofddorpSoundLab Cryrd 2', 'description': 'Smart Citizen Kit 2.1 with Urban Sensor Board', 'state': 'has_published', 'system_tags': ['offline', 'outdoor'], 'user_tags': ['I-CHANGE', 'Research'], 'last_reading_at': '2024-01-28T09:17:40Z', 'created_at': '2022-07-13T09:43:58Z', 'updated_at': '2024-06-27T17:03:34Z', 'notify': {'stopped_publishing': False, 'low_battery': False}, 'device_token': '[FILTERED]', 'postprocessing': None, 'location': {'ip': None, 'exposure': 'outdoor', 'elevation': None, 'latitude': 52.28161, 'longitude': 4.69947, 'geohash': 'u1736vw43w', 'city': 'Hoofddorp', 'country_code': 'NL', 'country': 'Netherlands'}, 'data_policy': {'is_private': '[FILTERED]', 'enable_forwarding': '[FILTERED]', 'precise_location': '[FILTERED]'}, 'hardware': {'name': 'SCK 2.1', 'type': 'SCK', 'version': '2.1', 'slug': 'sck:2,1', 'last_status_message': '[FILTERED]'}, 'owner': {'id': 8438, 'uuid': '3935d449-2516-4bac-a560-6d9bd369117e', 'username': 'jfry', 'url': None, 'avatar': 'https://smartcitizen.s3.amazonaws.com/avatars/default.svg', 'profile_picture': '', 'location': {'city': None, 'country': None, 'country_code': None}, 'device_ids': [15496]}, 'data': {'sensors': [{'id': 113, 'ancestry': '111', 'name': 'AMS CCS811 - TVOC', 'description': 'Total Volatile Organic Compounds Digital Indoor Sensor', 'unit': 'ppb', 'created_at': '2019-03-21T16:43:37Z', 'updated_at': '2019-03-21T16:43:37Z', 'uuid': '0c2a1afc-dc08-4066-aacb-0bde6a3ae6f5', 'default_key': 'tvoc', 'datasheet': None, 'unit_definition': None, 'measurement': {'id': 47, 'name': 'TVOC', 'description': 'Total volatile organic compounds is a grouping of a wide range of organic chemical compounds to simplify reporting when these are present in ambient air or emissions. Many substances, such as natural gas, could be classified as volatile organic compounds (VOCs).', 'unit': None, 'uuid': 'c6f9a729-1782-4da1-adc9-e88b7143e45c', 'definition': None}, 'value': 547.0, 'prev_value': 547.0, 'last_reading_at': '2024-01-28T09:17:40Z', 'tags': []}, {'id': 112, 'ancestry': '111', 'name': 'AMS CCS811 - eCO2', 'description': 'Equivalent Carbon Dioxide Digital Indoor Sensor', 'unit': 'ppm', 'created_at': '2019-03-21T16:43:37Z', 'updated_at': '2019-03-21T16:43:37Z', 'uuid': '995343c9-12ac-40c0-b6b9-19699e524f86', 'default_key': 'eco2', 'datasheet': None, 'unit_definition': None, 'measurement': {'id': 46, 'name': 'eCO2', 'description': 'Equivalent CO2 is the concentration of CO2 that would cause the same level of radiative forcing as a given type and concentration of greenhouse gas. Examples of such greenhouse gases are methane, perfluorocarbons, and nitrous oxide. CO2 is primarily a by-product of human metabolism and is constantly being emitted into the indoor environment by building occupants. CO2 may come from combustion sources as well. Associations of higher indoor carbon dioxide concentrations with impaired work performance and increased health symptoms have been attributed to correlation of indoor CO2 with concentrations of other indoor air pollutants that are also influenced by rates of outdoor-air ventilation.', 'unit': None, 'uuid': 'b6fee847-2bb6-4e1e-8e39-979612e2beb9', 'definition': None}, 'value': 1874.0, 'prev_value': 1874.0, 'last_reading_at': '2024-01-28T09:17:40Z', 'tags': []}, {'id': 14, 'ancestry': None, 'name': 'BH1730FVC - Light', 'description': 'Digital Ambient Light Sensor', 'unit': 'lux', 'created_at': '2015-02-02T18:24:56Z', 'updated_at': '2021-05 ...
# 0       2024-01-28T09:17:40Z   547  AMS CCS811 - TVOC
# 1       2024-01-28T09:16:40Z   547  AMS CCS811 - TVOC
# 2       2024-01-28T09:15:40Z   547  AMS CCS811 - TVOC
# 3       2024-01-28T09:14:40Z   542  AMS CCS811 - TVOC
# 4       2024-01-28T09:13:40Z   542  AMS CCS811 - TVOC
# ...                      ...   ...                ...
# 269943  2023-06-10T00:04:15Z    63  AMS CCS811 - TVOC
# 269944  2023-06-10T00:03:15Z    63  AMS CCS811 - TVOC
# 269945  2023-06-10T00:02:15Z    64  AMS CCS811 - TVOC
# 269946  2023-06-10T00:01:15Z    65  AMS CCS811 - TVOC
# 269947  2023-06-10T00:00:15Z    54  AMS CCS811 - TVOC
#
# [269948 rows x 3 columns], columns=[])

# %%
from ionbeam.core.bases import FinishMessage, FileMessage, MetaData
from ionbeam.aggregators import TimeAggregator

possible_actions = [a for a in actions if not isinstance(a, Source)]

message_history = []
while True:
    display(message)
    message_history.append(message)
    matching = [action for action in possible_actions if action.matches(message)]
    
    if not matching: 
        print("No more matches")
        break

    print("That matched with: ", [str(a) for a in matching])
    action = matching[0]

    # Special case for the TimeAggregator
    if action.__class__.__name__ == "TimeAggregator":
        list(action.process(message)) #need the list call here to pump the iterator to completion even if it doesn't return anything
        message = next(action.process(FinishMessage("We're done!")))
    else:
        message = next(action.process(message))
# Out:
# TabularMessage(metadata=MetaData(source_action_id=UUID('e3cfa3d1-c073-4f03-9f94-4e14bb190208'), state='raw', source=None, observation_variable=None, time_slice=None, encoded_format=None, filepath=None, variables=None, mars_request={}, unstructured={'device_id': 15496, 'sensor_key': 'tvoc', 'sensor_id': 113, 'component_id': 72773, 'rollup': '1s', 'function': 'avg', 'from': '2023-06-10T00:00:00Z', 'to': '2025-05-01T00:00:00Z', 'sample_size': 269948, 'device': {'id': 15496, 'uuid': 'a34e7c58-d235-432c-88b6-9d3bb48d0288', 'name': 'HoofddorpSoundLab Cryrd 2', 'description': 'Smart Citizen Kit 2.1 with Urban Sensor Board', 'state': 'has_published', 'system_tags': ['offline', 'outdoor'], 'user_tags': ['I-CHANGE', 'Research'], 'last_reading_at': '2024-01-28T09:17:40Z', 'created_at': '2022-07-13T09:43:58Z', 'updated_at': '2024-06-27T17:03:34Z', 'notify': {'stopped_publishing': False, 'low_battery': False}, 'device_token': '[FILTERED]', 'postprocessing': None, 'location': {'ip': None, 'exposure': 'outdoor', 'elevation': None, 'latitude': 52.28161, 'longitude': 4.69947, 'geohash': 'u1736vw43w', 'city': 'Hoofddorp', 'country_code': 'NL', 'country': 'Netherlands'}, 'data_policy': {'is_private': '[FILTERED]', 'enable_forwarding': '[FILTERED]', 'precise_location': '[FILTERED]'}, 'hardware': {'name': 'SCK 2.1', 'type': 'SCK', 'version': '2.1', 'slug': 'sck:2,1', 'last_status_message': '[FILTERED]'}, 'owner': {'id': 8438, 'uuid': '3935d449-2516-4bac-a560-6d9bd369117e', 'username': 'jfry', 'url': None, 'avatar': 'https://smartcitizen.s3.amazonaws.com/avatars/default.svg', 'profile_picture': '', 'location': {'city': None, 'country': None, 'country_code': None}, 'device_ids': [15496]}, 'data': {'sensors': [{'id': 113, 'ancestry': '111', 'name': 'AMS CCS811 - TVOC', 'description': 'Total Volatile Organic Compounds Digital Indoor Sensor', 'unit': 'ppb', 'created_at': '2019-03-21T16:43:37Z', 'updated_at': '2019-03-21T16:43:37Z', 'uuid': '0c2a1afc-dc08-4066-aacb-0bde6a3ae6f5', 'default_key': 'tvoc', 'datasheet': None, 'unit_definition': None, 'measurement': {'id': 47, 'name': 'TVOC', 'description': 'Total volatile organic compounds is a grouping of a wide range of organic chemical compounds to simplify reporting when these are present in ambient air or emissions. Many substances, such as natural gas, could be classified as volatile organic compounds (VOCs).', 'unit': None, 'uuid': 'c6f9a729-1782-4da1-adc9-e88b7143e45c', 'definition': None}, 'value': 547.0, 'prev_value': 547.0, 'last_reading_at': '2024-01-28T09:17:40Z', 'tags': []}, {'id': 112, 'ancestry': '111', 'name': 'AMS CCS811 - eCO2', 'description': 'Equivalent Carbon Dioxide Digital Indoor Sensor', 'unit': 'ppm', 'created_at': '2019-03-21T16:43:37Z', 'updated_at': '2019-03-21T16:43:37Z', 'uuid': '995343c9-12ac-40c0-b6b9-19699e524f86', 'default_key': 'eco2', 'datasheet': None, 'unit_definition': None, 'measurement': {'id': 46, 'name': 'eCO2', 'description': 'Equivalent CO2 is the concentration of CO2 that would cause the same level of radiative forcing as a given type and concentration of greenhouse gas. Examples of such greenhouse gases are methane, perfluorocarbons, and nitrous oxide. CO2 is primarily a by-product of human metabolism and is constantly being emitted into the indoor environment by building occupants. CO2 may come from combustion sources as well. Associations of higher indoor carbon dioxide concentrations with impaired work performance and increased health symptoms have been attributed to correlation of indoor CO2 with concentrations of other indoor air pollutants that are also influenced by rates of outdoor-air ventilation.', 'unit': None, 'uuid': 'b6fee847-2bb6-4e1e-8e39-979612e2beb9', 'definition': None}, 'value': 1874.0, 'prev_value': 1874.0, 'last_reading_at': '2024-01-28T09:17:40Z', 'tags': []}, {'id': 14, 'ancestry': None, 'name': 'BH1730FVC - Light', 'description': 'Digital Ambient Light Sensor', 'unit': 'lux', 'created_at': '2015-02-02T18:24:56Z', 'updated_at': '2021-05 ...
# 0       2024-01-28T09:17:40Z   547  AMS CCS811 - TVOC
# 1       2024-01-28T09:16:40Z   547  AMS CCS811 - TVOC
# 2       2024-01-28T09:15:40Z   547  AMS CCS811 - TVOC
# 3       2024-01-28T09:14:40Z   542  AMS CCS811 - TVOC
# 4       2024-01-28T09:13:40Z   542  AMS CCS811 - TVOC
# ...                      ...   ...                ...
# 269943  2023-06-10T00:04:15Z    63  AMS CCS811 - TVOC
# 269944  2023-06-10T00:03:15Z    63  AMS CCS811 - TVOC
# 269945  2023-06-10T00:02:15Z    64  AMS CCS811 - TVOC
# 269946  2023-06-10T00:01:15Z    65  AMS CCS811 - TVOC
# 269947  2023-06-10T00:00:15Z    54  AMS CCS811 - TVOC
#
# [269948 rows x 3 columns], columns=[])
# That matched with:  ['CSVParser']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 24
#      22     message = next(action.process(FinishMessage("We're done!")))
#      23 else:
# ---> 24     message = next(action.process(message))
#
# File ~/git/IonBeam-deployment/docker/IonBeam/src/ionbeam/parsers/csv.py:185, in CSVParser.process(self, rawdata)
#     178     raise ValueError(
#     179         f"Inappropriate message type passed to CSVParser: {rawdata}"
#     180         " This can also happen if you hot reload the code in a notebook, try restarting the kernel."
#     181     )
#     183 df = self.format_dataframe(df)
# --> 185 assert rawdata.metadata.variables is not None
#     187 if self.globals.split_data_columns:
#     188     # Split the data into data frames for each of the value types
#     189     for variable_column, df in self.split_columns(df):
#
# AssertionError:

# %%
m = message_history[-1]
m.data

# %%
df = pd.DataFrame({"class" : ["rd", "rd"], "col1" : [1,2], "col2" : [1,2]})
pyodc.encode_odb(df, "test.odb")

with open("test.odb", "rb") as f:
    pyfdb.archive(f.read())

# %%
import unicodedata as u

cs =  "¬!\"#£$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}~°Ωαβγδθλμπωϕ£"

def unicode_info(c):
    d = dict(
        character = c,
        utf8 = c.encode("utf_8"),
        # utf16 = c.encode("utf_16"),
        name = u.name(c, "NO NAME"),
        category = u.category(c),
    )
    if u.decomposition(c): d["decomposition"] = u.decomposition(c)
    if not u.is_normalized('NFKD', c): d["normalized_name"] = u.name(u.normalize('NFKD', c))
    if not u.is_normalized('NFKD', c): print("\n".join(f"{k}: {v}" for k, v in d.items()) + "\n")

for c in cs: unicode_info(c)

# %%
chr(0x1F600)

# %%
s = "".join(chr(i) for i in range(100000))
with open("test.txt", "wb") as f:
    f.write(s.encode("utf-8", errors='ignore'))

# %%
import unicodedata as u
u.name("·")
# Out:
# 'MIDDLE DOT'
