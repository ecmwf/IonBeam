# %%
# Allows code to live reload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Install
# ```sh
# # Install prerequisites
# pip install pyodc
#
# ```
#
# ## 2. Make an ECMWF account
# - Go to ecmwf.int/, click login at the top right and click register to make a new account.
# - Once logged in, go to api.ecmwf.int/v1/key/ to get your key.
# - Put it in `~/.ecmwfapirc` as directed.

# %%
# Load in the ECMWF token 
from pathlib import Path
import json
import requests
from IPython.display import JSON, display
from datetime import datetime as dt
from datetime import timedelta, timezone
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

with open(Path("~/.ecmwfapirc").expanduser(), "r") as f:
    api_creds = json.load(f)

print("Checking API credentials")
r = requests.get(f"https://api.ecmwf.int/v1/who-am-i?token={api_creds['key']}")
if r.status_code == 403: print("Your credentials are either wrong or need to be renewed at https://api.ecmwf.int/v1/key/")
r.raise_for_status()
JSON(r.json())
# Out:
# Checking API credentials

# %%
session = requests.Session()
session.headers["Authorization"] = f"Bearer {api_creds['key']}"

# %% [markdown]
# # API Endpoint
#
# Documentation http://ionbeam-ichange.ecmwf-ichange.f.ewcloud.host/docs

# %%
# url = "http://ionbeam-ichange.ecmwf-ichange.f.ewcloud.host/api/v1/"
url = "http://localhost:5002/api/v1/"

# %% [markdown]
# ### Get all stations

# %%
from datetime import datetime

stations = session.get(url + "stations", params = dict(platform = "acronet")).json()
print(f"{len(stations) = }")
# Out:
# len(stations) = 99

# %%
import folium

map = folium.Map(location=[44.226414, 9.532785], zoom_start=7)

for station in stations:
    p = station["location"]
    folium.CircleMarker(
        location=(station["location"]["lat"], station["location"]["lon"]),
        popup = station,
        radius=5, fill_color="orange", fill_opacity=0.4, color="black", weight=1,
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b985d8b85e6c495fc97ef7bb37a6ee0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b985d8b85e6c495fc97ef7bb37a6ee0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b985d8b85e6c495fc97ef7bb37a6ee0f = L.map(
#                 &quot;map_b985d8b85e6c495fc97ef7bb37a6ee0f&quot;,
#                 {
#                     center: [44.226414, 9.532785],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0df533824d5c9eeedfe002c2c4b57779 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0df533824d5c9eeedfe002c2c4b57779.addTo(map_b985d8b85e6c495fc97ef7bb37a6ee0f);
#
#
#             var circle_marker_77dee5f6a4eda8e210ab16afe2ecc10c = L.circleMarker(
#                 [44.43832, 8.641541],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b985d8b85e6c495fc97ef7bb37a6ee0f);
#
#
#         var popup_0a7df15e99fa8ebc12cd6efaaa2c4267 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2def2be25d0404044fae4530e081c6f3 = $(`&lt;div id=&quot;html_2def2be25d0404044fae4530e081c6f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;name&#x27;: &#x27;Rifugio Argentea&#x27;, &#x27;description&#x27;: &#x27;An Acronet station&#x27;, &#x27;platform&#x27;: &#x27;acronet&#x27;, &#x27;external_id&#x27;: &#x27;rifugio_argentea&#x27;, &#x27;internal_id&#x27;: &#x27;cbf531dac07bddb4&#x27;, &#x27;location&#x27;: {&#x27;lat&#x27;: 44.43832, &#x27;lon&#x27;: 8.641541}, &#x27;time_span&#x27;: {&#x27;start&#x27;: &#x27;2025-01-11T11:57:00Z&#x27;, &#x27;end&#x27;: &#x27;2025-01-15T15:44:00Z&#x27;}, &#x27;authors&#x27;: [{&#x27;name&#x27;: &#x27;acronet&#x27;}], &#x27;mars_request&#x27;: {&#x27;class&#x27;: &#x27;rd&#x27;, &#x27;expver&#x27;: &#x27;xxxx&#x27;, &#x27;stream&#x27;: &#x27;lwda&#x27;, &#x27;aggregation_type&#x27;: &#x27;chunked&#x27;, &#x27;date&#x27;: &#x27;20250111/to/20250115/by/1&#x27;, &#x27;platform&#x27;: &#x27;acronet&#x27;, &#x27;internal_id&#x27;: &#x27;cbf531dac07bddb4&#x27;}}&lt;/div&gt;`)[0];
#                 popup_0a7df15e99fa8ebc12cd6efaaa2c4267.setContent(html_2def2be25d0404044fae4530e081c6f3);
#
#
#
#         circle_marker_77dee5f6a4eda8e210ab16afe2ecc10c.bindPopup(popup_0a7df15e99fa8ebc12cd6efaaa2c4267)
#         ;
#
#
#
#
#             var circle_marker_be9b8a2950fbd33743a623c4fab3a481 = L.circleMarker(
#                 [44.10177, 9.925187],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b985d8b85e6c495fc97ef7bb37a6ee0f);
#
#
#         var popup_caa41a7445f241ab3b13f422acd69504 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec2faec03e04bc009175eab77df00be3 = $(`&lt;div id=&quot;html_ec2faec03e04bc009175eab77df00be3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;name&#x27;: &#x27;Trebiano&#x27;, &#x27;description&#x27;: &#x27;An Acronet station&#x27;, &#x27;platform&#x27;: &#x27;acronet&#x27;, &#x27;external_id&#x27;: &#x27;trebiano&#x27;, &#x27;internal_id&#x27;: &#x27;b364930470debbb5&#x27;, &#x27;location&#x27;: {&#x27;lat&#x27;: 44.10177, &#x27;lon&#x27;: 9.925187}, &#x27;time_span&#x27;: {&#x27;start&#x27;: &#x27;2025-01-11T11:57:00Z&#x27;, &#x27;end&#x27;: &#x27;2025-01-15T15:44:00Z&#x27;}, &#x27;authors&#x27;: [{&#x27;name&#x27;: &#x27;acronet&#x27;}], &#x27;mars_request&#x27;: {&#x27;class&#x27;: &#x27;rd&#x27;, &#x27;expver&#x27;: &#x27;xxxx&#x27;, &#x27;stream&#x27;: &#x27;lwda&#x27;, &#x27;aggregation_type&#x27;: &#x27;chunked&#x27;, &#x27;date&#x27;: &#x27;20250111/to/20250115/by/1&#x27;, &#x27;platform&#x27;: &#x27;acronet&#x27;, &#x27;internal_id&#x27;: &#x27;b364930470debbb5&#x27;}}&lt;/div&gt;`)[0];
#                 popup_caa41a7445f241ab3b13f422acd69504.setContent(html_ec2faec03e04bc009175eab77df00be3);
#
#
#
#         circle_marker_be9b8a2950fbd33743a623c4fab3

# %%
stations[0]
# Out:
# {'name': 'Rifugio Argentea',
#  'description': 'An Acronet station',
#  'platform': 'acronet',
#  'external_id': 'rifugio_argentea',
#  'internal_id': 'cbf531dac07bddb4',
#  'location': {'lat': 44.43832, 'lon': 8.641541},
#  'time_span': {'start': '2025-01-11T11:57:00Z', 'end': '2025-01-15T15:44:00Z'},
#  'authors': [{'name': 'acronet'}],
#  'mars_request': {'class': 'rd',
#   'expver': 'xxxx',
#   'stream': 'lwda',
#   'aggregation_type': 'chunked',
#   'date': '20250111/to/20250115/by/1',
#   'platform': 'acronet',
#   'internal_id': 'cbf531dac07bddb4'}}

# %% [markdown]
# ### Get stations with recent data

# %%
# %%time
from datetime import datetime, timedelta, UTC

recent_stations = session.get(url + "stations", params = {
    "start_time" : datetime.now(UTC) - timedelta(hours = 3),
    "platform" : "acronet",
}).json()
print(f"data ingested in last hour: {len(recent_stations) = }")
# Out:
# data ingested in last hour: len(recent_stations) = 99
# CPU times: user 2.02 ms, sys: 1.04 ms, total: 3.06 ms
# Wall time: 125 ms

# %%
granules = session.get(url + "list").json()
print(f"{len(granules) = }")
# Out:
# len(granules) = 6750

# %%
print(json.dumps(
    sorted(recent_stations, key = lambda s : datetime.fromisoformat(s["time_span"]["end"]) )[-1],
indent = 4))
# Out:
# {
#     "name": "Torre Civica",
#     "description": "An Acronet station",
#     "platform": "acronet",
#     "external_id": "torre_civica",
#     "internal_id": "759dbff9fe4985cd",
#     "location": {
#         "lat": 44.364265,
#         "lon": 8.205334
#     },
#     "time_span": {
#         "start": "2025-01-11T11:57:00Z",
#         "end": "2025-01-15T15:44:00Z"
#     },
#     "authors": [
#         {
#             "name": "acronet"
#         }
#     ],
#     "mars_request": {
#         "class": "rd",
#         "expver": "xxxx",
#         "stream": "lwda",
#         "aggregation_type": "chunked",
#         "date": "20250111/to/20250115/by/1",
#         "platform": "acronet",
#         "internal_id": "759dbff9fe4985cd"
#     }
# }

# %%
[station["name"] for station in by_platform["acronet"]][:10] + [f"... {len(by_platform["acronet"])} in total"]
# Out:
# ['Scuola Primaria Villa Sanguineti (Teglia)',
#  'Semaforo Nuovo',
#  'Piazza IV Novembre',
#  'Via Fiume',
#  'Stazione Rialto',
#  'Scuola Stella San Giovanni',
#  'Sambuco',
#  'Termi',
#  'Campi Sportivi Pigna',
#  'Viale Rimembranze',
#  '... 99 in total']

# %%
from random import choice

example_station = choice(by_platform["acronet"])
example_station
# Out:
# {'name': 'Campi Sportivi Pigna',
#  'description': 'An Acronet station',
#  'platform': 'acronet',
#  'external_id': 'campi_sportivi_pigna',
#  'internal_id': '3107c0e6dad80774',
#  'location': {'lat': 43.930916, 'lon': 7.666303},
#  'time_span': {'start': '2025-01-14T19:08:00Z', 'end': '2025-01-15T14:58:00Z'},
#  'authors': [{'name': 'acronet'}],
#  'mars_request': {'class': 'rd',
#   'expver': 'xxxx',
#   'stream': 'lwda',
#   'aggregation_type': 'chunked',
#   'date': '20250114/to/20250115/by/1',
#   'platform': 'acronet',
#   'internal_id': '3107c0e6dad80774'}}

# %% [markdown]
# ### Data granules corresponging to an acronet station

# %%
data_granules = session.get(url + "list", params = example_station["mars_request"]).json()
datetimes = [(g["mars_request"]["date"], g["mars_request"]["time"]) for g in data_granules]
assert len(datetimes) == len(set(datetimes))
datetimes
# Out:
# [('20250114', '1800'),
#  ('20250114', '1900'),
#  ('20250114', '2000'),
#  ('20250114', '2100'),
#  ('20250114', '2200'),
#  ('20250114', '2300'),
#  ('20250115', '0000'),
#  ('20250115', '0100'),
#  ('20250115', '0200'),
#  ('20250115', '0300'),
#  ('20250115', '0400'),
#  ('20250115', '0500'),
#  ('20250115', '0600'),
#  ('20250115', '0700'),
#  ('20250115', '0800'),
#  ('20250115', '0900'),
#  ('20250115', '1000'),
#  ('20250115', '1100'),
#  ('20250115', '1200'),
#  ('20250115', '1300'),
#  ('20250115', '1400'),
#  ('20250115', '1500')]

# %%
import folium
p = (example_station["location"]["lat"], example_station["location"]["lon"])
map = folium.Map(location=p, zoom_start=13)

# Add the point as a marker
folium.Marker(
    location=p,
    popup = example_station,
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72f89a1de38ca038cf5291fe366fc46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72f89a1de38ca038cf5291fe366fc46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72f89a1de38ca038cf5291fe366fc46 = L.map(
#                 &quot;map_b72f89a1de38ca038cf5291fe366fc46&quot;,
#                 {
#                     center: [43.930916, 7.666303],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c905ee8ccb38a50f3fb529bc584ac1de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c905ee8ccb38a50f3fb529bc584ac1de.addTo(map_b72f89a1de38ca038cf5291fe366fc46);
#
#
#             var marker_d32848b0f9e9bd35e41587da35825311 = L.marker(
#                 [43.930916, 7.666303],
#                 {}
#             ).addTo(map_b72f89a1de38ca038cf5291fe366fc46);
#
#
#         var popup_4c6c7336099acbe7292f43b4dba2e74f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_afdbfb1a28e5ebc32f2fbe6131c84dfb = $(`&lt;div id=&quot;html_afdbfb1a28e5ebc32f2fbe6131c84dfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{&#x27;name&#x27;: &#x27;Campi Sportivi Pigna&#x27;, &#x27;description&#x27;: &#x27;An Acronet station&#x27;, &#x27;platform&#x27;: &#x27;acronet&#x27;, &#x27;external_id&#x27;: &#x27;campi_sportivi_pigna&#x27;, &#x27;internal_id&#x27;: &#x27;3107c0e6dad80774&#x27;, &#x27;location&#x27;: {&#x27;lat&#x27;: 43.930916, &#x27;lon&#x27;: 7.666303}, &#x27;time_span&#x27;: {&#x27;start&#x27;: &#x27;2025-01-14T19:08:00Z&#x27;, &#x27;end&#x27;: &#x27;2025-01-15T14:58:00Z&#x27;}, &#x27;authors&#x27;: [{&#x27;name&#x27;: &#x27;acronet&#x27;}], &#x27;mars_request&#x27;: {&#x27;class&#x27;: &#x27;rd&#x27;, &#x27;expver&#x27;: &#x27;xxxx&#x27;, &#x27;stream&#x27;: &#x27;lwda&#x27;, &#x27;aggregation_type&#x27;: &#x27;chunked&#x27;, &#x27;date&#x27;: &#x27;20250114/to/20250115/by/1&#x27;, &#x27;platform&#x27;: &#x27;acronet&#x27;, &#x27;internal_id&#x27;: &#x27;3107c0e6dad80774&#x27;}}&lt;/div&gt;`)[0];
#                 popup_4c6c7336099acbe7292f43b4dba2e74f.setContent(html_afdbfb1a28e5ebc32f2fbe6131c84dfb);
#
#
#
#         marker_d32848b0f9e9bd35e41587da35825311.bindPopup(popup_4c6c7336099acbe7292f43b4dba2e74f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Giving the "mars_request" to the `list` endpoint gives the list of data granules available from the list endpoint. For the acronet data and other continuous streams, there is an additional key "time" which gives the begining of the interval in the format HHMM
#
# In the MARS system one needs to deal with these separate `date` and `time` fields but for convenience two special arguments are added to the API: `start_time` and `end_time`, these ISO formatted fields will be used to return data granules within the defined temporal region.
#
# * If `start_time` or `end_time` are supplied, `date` and `time` are ignored.
# * If `start_time` or `end_time` fall within the boundary of a data chunk, the whole chunk will be returned.
# * If only one of `start_time` or `end_time` are supplied, the other is ignored.
#
# * If neither `start_time` nor `end_time` are supplied, `date` and `time` will be used following the typical MARS language.
#
# The `list` endpoint is not necessary, but can be useful to retrieve the available chunks for a mars request. The arguments to `list` and `retrieve` are the same, list returns what data granules exist and `retrieve` returns the data granules concatenated together.

# %% [markdown]
# ### Getting data for an acronet station

# %%
example_station["mars_request"]
# Out:
# {'class': 'rd',
#  'expver': 'xxxx',
#  'stream': 'lwda',
#  'aggregation_type': 'chunked',
#  'date': '20250114/to/20250115/by/1',
#  'platform': 'acronet',
#  'internal_id': '3107c0e6dad80774'}

# %%
# %%time

from io import BytesIO
example_station = by_platform["acronet"][-1]
now = datetime.now(UTC)
args = {
    "start_time" : (now - timedelta(hours = 5)).isoformat(),
    "end_time": (now - timedelta(hours = 0)).isoformat(),
}

granules = session.get(url + "list", params = example_station["mars_request"] | args).json()
data = session.get(url + "retrieve", params = example_station["mars_request"] | args | dict(format = "csv"))

if not data.ok:
    print("error: ", data.json())
else:
    df = pd.read_csv(BytesIO(data.content))
    df
# Out:
# CPU times: user 5.61 ms, sys: 5.45 ms, total: 11.1 ms
# Wall time: 886 ms

# %%
df.columns
# Out:
# Index(['station_id', 'station_name', 'author', 'datetime', 'lat', 'lon',
#        'wind_direction_near_surface', 'wind_speed_near_surface',
#        'relative_humidity_near_surface', 'rainfall', 'battery_level',
#        'air_temperature_near_surface', 'signal_strength', 'wind_gust'],
#       dtype='object')

# %%
set(g["mars_request"]["internal_id"] for g in granules)
granules[-3:]
# Out:
# [{'mars_request': {'class': 'rd',
#    'expver': 'xxxx',
#    'stream': 'lwda',
#    'aggregation_type': 'chunked',
#    'date': '20250115',
#    'internal_id': '06cd83f8ed2fd88b',
#    'platform': 'acronet',
#    'time': '1300',
#    'version': '1'},
#   'url': '/api/v1/retrieve?class=rd&expver=xxxx&stream=lwda&aggregation_type=chunked&date=20250115&internal_id=06cd83f8ed2fd88b&platform=acronet&time=1300&version=1',
#   'datetime': '2025-01-15T13:00:00Z'},
#  {'mars_request': {'class': 'rd',
#    'expver': 'xxxx',
#    'stream': 'lwda',
#    'aggregation_type': 'chunked',
#    'date': '20250115',
#    'internal_id': '06cd83f8ed2fd88b',
#    'platform': 'acronet',
#    'time': '1400',
#    'version': '1'},
#   'url': '/api/v1/retrieve?class=rd&expver=xxxx&stream=lwda&aggregation_type=chunked&date=20250115&internal_id=06cd83f8ed2fd88b&platform=acronet&time=1400&version=1',
#   'datetime': '2025-01-15T14:00:00Z'},
#  {'mars_request': {'class': 'rd',
#    'expver': 'xxxx',
#    'stream': 'lwda',
#    'aggregation_type': 'chunked',
#    'date': '20250115',
#    'internal_id': '06cd83f8ed2fd88b',
#    'platform': 'acronet',
#    'time': '1500',
#    'version': '1'},
#   'url': '/api/v1/retrieve?class=rd&expver=xxxx&stream=lwda&aggregation_type=chunked&date=20250115&internal_id=06cd83f8ed2fd88b&platform=acronet&time=1500&version=1',
#   'datetime': '2025-01-15T15:00:00Z'}]

# %% [markdown]
# ### Plot showing data granule boundaries and station time span along with data
#
# Any missing granules will show up as white areas
#
# - Green vertical lines: data granule boundaries
# - Green shaded: places we have data
# - Black vertical lines: Station time span
# - Red vertical lines: User timespan request

# %%
show_granule_boundaries = True

df["datetime"] = pd.to_datetime(df["datetime"])

ys_to_plot = df.select_dtypes(include='number').columns

axes = df.plot(
    x = "datetime",
    y = ys_to_plot,
    subplots=True, layout=(len(ys_to_plot), 1), figsize=(8, 1*len(ys_to_plot)), sharex=True, rot=90)

for ax in axes[:, 0]:
    if show_granule_boundaries:
        for g in granules:
            date, time = g["mars_request"]["date"], g["mars_request"]["time"]
            dt = datetime.strptime(date + time, "%Y%m%d%H%M")
            dt2 = dt + timedelta(minutes = 60)
            ax.axvline(dt, linestyle = "dotted", color = "green")
            ax.axvline(dt2, linestyle = "dotted", color = "green")
            ax.axvspan(dt, dt2, alpha = 0.1, color = "green")

    ax.axvline(datetime.now(UTC), linestyle = "dotted", color = "black")

    # for d in example_station["time_span"].values():
    #     ax.axvline(datetime.fromisoformat(d), linestyle = "dotted", color = "black")

    # ax.axvline(args["start_time"], linestyle = "dotted", color = "red")
    # ax.axvline(args["end_time"], linestyle = "dotted", color = "red")
    



plt.tight_layout()
